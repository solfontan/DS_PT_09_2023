# %% [markdown]
# La expresión correcta debería ser simplemente `row + ship`.
#
# Entonces, la expresión `all(row:row+ship, column) != X` verificaría si todos los elementos en una fila específica (definida por `row` a `row + ship`) y en una columna específica (definida por `column`) no son iguales a `X`. Si al menos uno de los elementos en la fila y columna dadas no es igual a `X`, la expresión devolverá `False`, indicando que la condición no se cumple en la fila y columna específicas.
#
# Claro, si escribes `(all(row:row-ship:-1, column) != 'x')`, esto cambia significativamente el significado de la expresión. Aquí está cómo se interpretaría:
#
# 1. `row:row-ship:-1`: Esta parte de la expresión es una rebanada (slice) en Python. Está tomando una secuencia de elementos que comienza en `row`, va hacia atrás en la secuencia con un paso de -1 y termina en `row - ship`. Esto implica que estás seleccionando una secuencia que va desde `row` hasta `row - ship` en orden inverso.
#
# 2. `column`: Esto parece ser una variable que representa una columna en una matriz bidimensional o una estructura de datos similar.
#
# 3. `!= 'x'`: Esto verifica si el valor en la matriz en la posición especificada (según la rebanada y la columna) no es igual a la cadena de caracteres 'x'.
#
# En resumen, esta expresión verifica si todos los elementos en una fila específica (definida por `row` a `row - ship` en orden inverso) y en una columna específica (definida por `column`) no son iguales a la cadena de caracteres 'x'. Si todos los elementos cumplen esta condición, la expresión devolverá `True`, lo que significa que la condición se cumple para toda la fila y columna especificadas. Si al menos uno de los elementos no cumple la condición, la expresión devolverá `False`, indicando que la condición no se cumple en la fila y columna dadas.

# %% [markdown]
# ¡Me alegra que hayas resuelto el problema! En efecto, cuando intentas iterar a través de una lista que contiene una mezcla de diccionarios y cadenas, es importante asegurarse de que todas las iteraciones sean consistentes en cuanto al tipo de datos que manejas. Al intentar acceder a las claves en un diccionario, Python espera que todos los elementos de la lista sean diccionarios para que el código funcione sin errores.
#
# Si en algún momento necesitas indicar que no se pudo colocar un barco, es preferible agregar un diccionario de valores especiales en lugar de una cadena, de modo que puedas mantener la coherencia en el tipo de datos dentro de la lista.
#
# Si tienes más preguntas o necesitas más ayuda, no dudes en preguntar. ¡Disfruta del juego de Batalla Naval!

# %% [markdown]
# En este código, `barco_encontrado` se establece inicialmente en `None` y se utiliza como una bandera para determinar si el disparo del usuario alcanzó un barco o no. Si se alcanza un barco, la variable `barco_encontrado` se actualizará con la información del barco que fue alcanzado. Si no se alcanza ningún barco, `barco_encontrado` permanecerá como `None`, lo que indica que el disparo del usuario no alcanzó ningún barco en el tablero.
#
# Aquí hay una explicación de cómo funciona:
#
# 1. `barco_encontrado` se establece en `None` al comienzo de cada turno.
#
# 2. Luego, el código recorre la lista de `barcos` para verificar si las coordenadas proporcionadas por el usuario coinciden con la posición de algún barco.
#
# 3. Si se encuentra un barco en las coordenadas proporcionadas, la variable `barco_encontrado` se actualiza con la información del barco que fue alcanzado. Esto se hace utilizando `barco_encontrado = barco_info`.
#
# 4. Después de verificar todos los barcos, si `barco_encontrado` no es `None`, significa que se alcanzó un barco, y el barco se elimina de la lista de `barcos`. Esto es lo que hace la línea `barcos.remove(barco_encontrado)`. Esto garantiza que un barco solo pueda ser alcanzado una vez y evita que se cuente como alcanzado nuevamente en disparos futuros.
#
# 5. Si `barco_encontrado` todavía es `None` después de verificar todos los barcos, significa que el disparo del usuario no alcanzó ningún barco. En este caso, el código actualiza el `tablero` con un `'-'` para marcar esa posición como un disparo fallido.
#
# La condición `if barco_encontrado` se utiliza para verificar si se alcanzó un barco en el turno actual. Si se alcanzó un barco, el código ejecuta el bloque dentro de esa declaración `if` para marcar el barco como alcanzado y eliminarlo de la lista de barcos. Si no se alcanzó ningún barco, el código ejecuta el bloque `else` para marcar la posición como un fallo y mostrar "Lo siento, fallaste".

# %%
while barcos:
        user_answer_2 = input('¿Deseas disparar? S/N: ')
        if user_answer_2.lower() != 's':
            break
            
        print(tablero_inicial)
        ataque_user = input('Escriba las coordenas separadas por comas. RECUERDA FILA, COLUMNA:')
        fila,columna = map(int, ataque_user.split(','))
            
        barco_encontrado = None
        for barco_info in barcos:
            if barco_info['dirección'] == 'norte' and barco_info['fila'] == fila and barco_info['columna'] == columna:
                ship = barco_info['barco']
                tablero[fila:fila - ship:-1, columna] = ' '.join(['#'] * ship)
                print('Barco Hundido')
                barco_encontrado = barco_info
                break

            elif barco_info['dirección'] == 'sur' and barco_info['fila'] == fila and barco_info['columna'] == columna:  
                ship = barco_info['barco']                 
                tablero[fila:fila+ship:,columna] = ' '.join(['#'] * ship)        
                print('Barco Hundido')
                barco_encontrado = barco_info
                break     
     
      elif barco_info['dirección'] == 'oeste' and barco_info['fila'] == fila and barco_info['columna'] == columna:     
                ship = barco_info['barco']             
                tablero[fila,columna:columna-ship:-1] = ' '.join(['#'] * ship)        
                print('Barco Hundido')
                barco_encontrado = barco_info
                break

            
            elif barco_info['dirección'] == 'este' and barco_info['fila'] == fila and barco_info['columna'] == columna:    
                ship = barco_info['barco']               
                tablero[fila,columna:columna+ship:] = ' '.join(['#'] * ship)        
                print('Barco Hundido')
                barco_encontrado = barco_info
                break
                
        if barco_encontrado:
            barcos.remove(barco_encontrado)
        else:
            if tablero[fila, columna] == ' ':
                print('Lo siento, fallaste')
                tablero[fila, columna] = '-'
            else:
                print('Ya has disparado a esa coordenada')

    print(tablero)

# %%
import numpy as np

tablero = np.full((11,11), fill_value=' ')
indice = -1
for i in range(len(tablero)):
    tablero[0][0] = ' '
    indice += 1
    tablero[0][i] = indice
    tablero[i][0] = indice

barcos = [{'fila': 5,'columna':6,'dirección':'norte', 'barco' : 4},{'fila': 2,'columna':3,'dirección':'sur', 'barco' : 2}]

while barcos:
        user_answer_2 = input('¿Deseas disparar? S/N: ')
        if user_answer_2.lower() != 's':
            break
            
        ataque_user = input('Escriba las coordenas separadas por comas. RECUERDA FILA, COLUMNA:')
        fila,columna = map(int, ataque_user.split(','))
            
        barco_encontrado = None
        for barco_info in barcos:
            if barco_info['fila'] == fila and barco_info['columna'] == columna:
                if barco_info['dirección'] == 'norte':
                    ship = barco_info['barco']
                    tablero[fila:fila - ship:-1, columna] = ' '.join(['#'] * ship)
                    print(tablero)
                    print('Barco Hundido')
                    barco_encontrado = barco_info

                elif barco_info['dirección'] == 'sur':  
                    ship = barco_info['barco']                 
                    tablero[fila:fila+ship,columna] = ' '.join(['#'] * ship)        
                    print(tablero)
                    print('Barco Hundido')
                    barco_encontrado = barco_info
                
                elif barco_info['dirección'] == 'oeste':
                    ship = barco_info['barco']             
                    tablero[fila,columna:columna-ship:-1] = ' '.join(['#'] * ship)        
                    print(tablero)
                    print('Barco Hundido')
                    barco_encontrado = barco_info

            
                elif barco_info['dirección'] == 'este':
                    ship = barco_info['barco']               
                    tablero[fila,columna:columna+ship] = ' '.join(['#'] * ship)        
                    print(tablero)
                    print('Barco Hundido')
                    barco_encontrado = barco_info

                
        if barco_encontrado:
            barcos.remove(barco_encontrado)
        else:
            if tablero[fila, columna] == ' ':
                print('Lo siento, fallaste')
                tablero[fila, columna] = '-'
                print(tablero)
            else:
                print('Ya has disparado a esa coordenada')

# %%
tablero = np.full((10,10), fill_value=' ')
print(tablero)

def barcomaquina():
    
    ship = np.random.randint(2,5) # Barcos de dos, tres y cuatro
    print('medida del barco: ', ship)
    row = np.random.randint(1,11) # fila
    print('Fila: ',row)
    column = np.random.randint(1,11)
    print('Columna: ', column)

    rows, columns = tablero.shape
    print('forma: ', rows, columns)
    direccion = np.random.choice(['horizontal','vertical']) 
    print('posicion:', direccion)

    continuar = True

    if direccion == 'horizontal':
        while continuar:           
            if column + ship >= columns:
                print('No se puede ubicar el barco')
                continuar = False
                    
            elif column + ship < columns and tablero[row,column] != 'X':              
                tablero[row,column] = 'X'
                column = column + 1                         
                ship = ship - 1
                
                if ship == 0:
                    print(tablero)
                    print('Barco ubicado')
                    continuar = False
            else:
                return 'Ya hay un barco'
          
            if direccion == 'vertical':
                if row + ship >= rows:
                    print('Nose puede ubicar el barco')
                    continuar = False

                elif row + ship < rows and tablero[row,column] != 'X':              
                    tablero[row,column] = 'X'              
                    row = row + 1                         
                    ship = ship - 1
                
                    if ship == 0:
                        print(tablero)
                        print('Barco ubicado')
                        continuar = False
                    
                else:
                    return 'Ya hay un barco'


# def atacar(fila: int, columna: int, ship) :
#     continuar = True
#     while continuar:
#         if tablero[fila,columna] == 'X':
#             tablero[fila,columna] = '#'
        #     columna = columna + 1                         
        #     ship = ship - 1           
                
        #     if ship == 0:
        #         print(tablero)
        #         print('Barco Hundido')
        #         continuar = False
            
        # elif tablero[fila,columna] == 'X':
        #     tablero[fila,columna] = '#'
        #     fila = fila + 1                         
        #     ship = ship - 1
            
        #     if ship == 0:
        #         print(tablero)
        #         print('Barco Hundido')
        #         continuar = False

                
        # if tablero[fila,columna] != 'X':
        #     print('Lo siento, fallaste')
        #     tablero[fila,columna] = '-'
        #     print(tablero)
            
        # else:
        #     print('error')

# %%
import numpy as np

tablero = np.full((10,10), fill_value=' ')
print(tablero)
# indice = 0
# for i in tablero:
#     if i == tablero[0] and i == tablero[0][0]:
#         indice = indice + 1
#         print(indice)

def barcomaquina():
    ship = np.random.randint(2,5) # Barcos de dos-tres-cuatro posiciones
    row = np.random.randint(1,11) 
    column = np.random.randint(1,11)
    rows, columns = tablero.shape
    position = np.random.choice(['horizontal','vertical']) 

    info_barco = {'barco' : ship,
                    'fila' : row,
                    'columna' : column,
                    'dirección' : position}
    
    print(info_barco, '\n')
    
    continuar = True

    if position == 'horizontal':
        while continuar:           
            if column + ship >= columns:
                print('No se puede ubicar el barco')
                continuar = False
                    
            elif column + ship <= columns and all(tablero[row,column:column+ship] != 'X'):  #Comprueba que las casillas siguientes no contengan 'X'           
                tablero[row,column:column+ship] = 'X' 
                print(tablero)
                print('Barco ubicado')
                continuar = False
                #tablero[row,column] = 'X'
                #column = column + 1                         
                #ship = ship - 1
                #     if ship == 0:
                #     print(tablero)
                #     print('Barco ubicado')
                #     continuar = False

            else:
                return 'Ya hay un barco'
          
    if position == 'vertical':
        while continuar:
            if row + ship >= rows:
                print('Nose puede ubicar el barco')
                continuar = False

            elif row + ship <= rows and all(tablero[row:row+ship,column] != 'X'):              
                tablero[row:row+ship,column] = 'X'              
                print(tablero)
                print('Barco ubicado')
                continuar = False
            else:
                return 'Ya hay un barco'

# %%
import numpy as np

tablero = np.full((11,11), fill_value=' ')
indice = -1
for i in range(len(tablero)):
    tablero[0][0] = ' '
    indice += 1
    tablero[0][i] = indice
    tablero[i][0] = indice
      
print(tablero)
def barcomaquina():
    cant_ship = 5  # Número total de barcos
    rows, columns = tablero.shape
    
    # Crear un diccionario para almacenar la información de los barcos
    barcos = []
    
    while cant_ship > 0:
        ship = np.random.randint(2, 5)  # Barcos de dos-tres-cuatro posiciones
        row = np.random.randint(1, 11)
        column = np.random.randint(1, 11)
        position = np.random.choice(['norte', 'sur', 'este', 'oeste'])

        if position == 'norte' and all(tablero[row:row-ship:-1,column] != 'X'):    
            if row - ship > 0 and row + ship <= rows: # Norte/sur movimiento vertical       
                tablero[row:row-ship:-1,column] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
            
        elif position == 'sur' and all(tablero[row:row+ship,column] != 'X'): #Comprueba que las casillas siguientes no contengan 'X'           
            if row - ship > 0 and row + ship <= rows: 
                tablero[row:row+ship,column] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
        
        elif position == 'oeste' and all(tablero[row,column:column-ship:-1] != 'X'):              
            if column - ship > 0 and column + ship <= columns:       
                tablero[row,column:column-ship:-1] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
            
        elif position == 'este' and all(tablero[row,column:column+ship] != 'X'):   
            if column - ship > 0 and column + ship <= columns:
                tablero[row,column:column+ship] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
        else:
            mensaje = 'No se pudo agregar el barco'
            barcos.append(mensaje)
            cant_ship = cant_ship
                
    # Imprimir el tablero
    print(tablero)
    
    # Imprimir la información de los barcos
    print("Información de los barcos:")
    for index, barco_info in enumerate(barcos):
        print(f"Barco {index + 1}: {barco_info}")

# %%
import numpy as np

print('****************************************** \n\tBienvenido a Batalla Naval! \t\n******************************************')
print('El juego consiste en encontrar los cinco barcos que dentro del mar.\nLa batalla termina cuando todos los barcos esten hundidos.\n¡Éxitos, Capitán!')
user_answer = input('¿Comenzamos? S/N: ')

if user_answer.lower() == 's':
    print('\nBien, empecemos...')
    
    tablero = np.full((11,11), fill_value=' ')
    indice = -1
    for i in range(len(tablero)):
        tablero[0][0] = ' '
        indice += 1
        tablero[0][i] = indice
        tablero[i][0] = indice
        
    # print(tablero)
# else:
#     print("No se ha comenzado el juego")
    # def barcomaquina():
    cant_ship = 5  # Número total de barcos
    rows, columns = tablero.shape
        
    # Crear un diccionario para almacenar la información de los barcos
    barcos = []
        
    while cant_ship > 0:
        ship = np.random.randint(2, 5)  # Barcos de dos-tres-cuatro posiciones
        row = np.random.randint(1, 11)
        column = np.random.randint(1, 11)
        position = np.random.choice(['norte', 'sur', 'este', 'oeste'])

        if position == 'norte' and all(tablero[row:row-ship:-1,column] != 'X'):    
            if row - ship > 0 and row + ship <= rows: # Norte/sur movimiento vertical       
                tablero[row:row-ship:-1,column] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
                
        elif position == 'sur' and all(tablero[row:row+ship,column] != 'X'): #Comprueba que las casillas siguientes no contengan 'X'           
            if row - ship > 0 and row + ship <= rows: 
                tablero[row:row+ship,column] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
        
        elif position == 'oeste' and all(tablero[row,column:column-ship:-1] != 'X'):              
            if column - ship > 0 and column + ship <= columns:       
                tablero[row,column:column-ship:-1] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
            
        elif position == 'este' and all(tablero[row,column:column+ship] != 'X'):   
            if column - ship > 0 and column + ship <= columns:
                tablero[row,column:column+ship] = 'X' 
                cant_ship = cant_ship - 1
                barco_info = {
                    'barco': ship,
                    'fila': row,
                    'columna': column,
                    'dirección': position
                }
                barcos.append(barco_info)
        else:
            mensaje = 'No se pudo agregar el barco'
            barcos.append(mensaje)
            cant_ship = cant_ship
                
    # Imprimir el tablero
    print(tablero)
    
    # Imprimir la información de los barcos
    # print("Información de los barcos:")
    # for index, barco_info in enumerate(barcos):
    #     print(f"Barco {index + 1}: {barco_info}")
    
    user_answer_2 = input('¿Deseas disparar? S/N: ')
    if user_answer_2.lower() == 's':
        print(tablero)
        
        ataque_user = input('Escriba las coordenas separadas por comas. RECUERDA FILA, COLUMNA:')
        fila,columna = ataque_user.split(',')
        
        continuar = True
        while continuar:
            if barco_info[position] == 'norte' and barco_info[row] == fila and barco_info[column] == columna:                  
                tablero[fila:fila-ship:-1,columna] = ' '.join(['#'] * ship)        
                print(tablero)
                print('Barco Hundido')
                continuar = False
                
            elif barco_info[position] == 'sur' and barco_info[row] == fila and barco_info[column] == columna:                  
                tablero[fila:fila+ship:,columna] = ' '.join(['#'] * ship)        
                print(tablero)
                print('Barco Hundido')
                continuar = False
                
            elif barco_info[position] == 'oeste' and barco_info[row] == fila and barco_info[column] == columna:                  
                tablero[fila,columna:columna-ship:-1] = ' '.join(['#'] * ship)        
                print(tablero)
                print('Barco Hundido')
                continuar = False
            if barco_info[position] == 'norte' and barco_info[row] == fila and barco_info[column] == columna:                  
                tablero[fila,columna:columna+ship:] = ' '.join(['#'] * ship)        
                print(tablero)
                print('Barco Hundido')
                continuar = False

            elif tablero[fila,columna] == ' ':
                print('Lo siento, fallaste')
                tablero[fila,columna] = '-'
                print(tablero)
                continuar = False
                
            elif tablero[fila,columna] == '#':
                print('Ya has disparado a esa coordenada')
                print(tablero)
                continuar = False
                
            else:
                print('error')
                break
